# %% [markdown]
# Câu 1

# %%
import numpy as np

x = []
for i in range(10):
  x.append(np.random.randint(-14, 14))
print(x)
# Out:
# [-5, -4, 6, -9, -10, 13, -3, -1, -7, -9]

# %% [markdown]
# Câu 2

# %%
x = np.sort(x)
print(x)
# Out:
# [-10  -9  -9  -7  -5  -4  -3  -1   6  13]

# %% [markdown]
# Câu 3

# %%
import matplotlib.pyplot as plt

A = 2*x + 1
B = x**2

plt.plot(x, A, 'r', label="2*x + 1")
plt.plot(x, B, 'b', label="x**2")
plt.legend()
plt.show()
